# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from scipy.stats import ttest_ind, zscore
from summarytools import dfSummary

# %% [markdown]
# # Load Engineered data

# %%
malicious_features = pd.read_pickle("data/malicious_features_numeric.pkl")
benign_features = pd.read_pickle("data/benign_features_numeric.pkl")

# %%
malicious_features
# Out:
#            Timestamp  Source Port  Destination Port  \
# 0       1.540446e+09      21074.0              80.0
# 1       1.540446e+09      20532.0            8280.0
# 7       1.540446e+09       2440.0              53.0
# 8       1.540446e+09         53.0            2440.0
# 9       1.540446e+09      21074.0              80.0
# ...              ...          ...               ...
# 764121  1.540454e+09      32761.0           10240.0
# 764122  1.540454e+09      35284.0              53.0
# 764124  1.540454e+09      47157.0              80.0
# 764125  1.540454e+09      46453.0            8280.0
# 764136  1.540454e+09       3570.0              53.0
#
#                                                   Payload  Packet Length  \
# 0                                                 Padding             26
# 1                                                 Padding             26
# 7       DNS Qry "b'xmpp.samsungsmartcam.com.Speedport_...             83
# 8                                                DNS Ans              83
# 9                                                 Padding             26
# ...                                                   ...            ...
# 764121                                                Raw             48
# 764122                    DNS Qry "b'time.windows.com.'"              42
# 764124                                            Padding             26
# 764125                                            Padding             26
# 764136  DNS Qry "b'north-america.pool.ntp.org.Speedpor...             85
#
#         Protocol  src_ip_total_bytes  dst_ip_total_bytes  Numeric Source IP  \
# 0            6.0                  26                  26         3232236140
# 1            6.0                  52                  26         3232236140
# 7           17.0                  83                  83         3232236147
# 8           17.0                  83                  83         3232236033
# 9            6.0                  78                  52         3232236140
# ...          ...                 ...                 ...                ...
# 764121      17.0             2207242              633840         3232236140
# 764122      17.0              241142              158024         3232236141
# 764124       6.0             2207268              163490         3232236140
# 764125       6.0             2207294              163436         3232236140
# 764136      17.0              883618             1423395         3232236147
#
#         Numeric Destination IP  dst_port_freq_encoded  Interarrival
# 0                    873999171               0.114505           NaN
# 1                    874070778               0.040794      0.000005
# 7                   3232236033               0.216419      0.457747
# 8                   3232236147               0.000013      0.002058
# 9                    873999171               0.114505      0.042112
# ...                        ...                    ...           ...
# 764121              1035740632               0.406152      0.000002
# 764122               134744072               0.216419      0.153157
# 764124               873999171               0.114505      0.301136
# 764125               874070778               0.040794      0.000078
# 764136              3232236033               0.216419      0.085632
#
# [154090 rows x 12 columns]

# %%
benign_features
# Out:
#           Timestamp  Source Port  Destination Port Payload  Packet Length  \
# 4      1.355254e+09        646.0             646.0     Raw             42
# 5      1.355254e+09        646.0             646.0     Raw             42
# 6      1.355254e+09        646.0             646.0     Raw             42
# 7      1.355254e+09        646.0             646.0     Raw             42
# 26     1.355254e+09        646.0             646.0     Raw             42
# ...             ...          ...               ...     ...            ...
# 38585  1.671036e+09       1812.0           10048.0  Radius             40
# 38586  1.671036e+09       3860.0            1812.0  Radius            112
# 38587  1.671036e+09       1812.0            3860.0  Radius            104
# 38588  1.671036e+09       3373.0            1812.0  Radius            120
# 38589  1.671036e+09       1812.0            3373.0  Radius            199
#
#        Protocol  src_ip_total_bytes  dst_ip_total_bytes  Numeric Source IP  \
# 4          17.0                  42                  42          167772161
# 5          17.0                  84                  84          167772161
# 6          17.0                  42                 126          167772162
# 7          17.0                  84                 168          167772162
# 26         17.0                 126                 210          167772162
# ...         ...                 ...                 ...                ...
# 38585      17.0                 264                4648         3270968603
# 38586      17.0               91433                 575         3270968577
# 38587      17.0                 368                4752         3270968603
# 38588      17.0               91553                 695         3270968577
# 38589      17.0                 567                4951         3270968603
#
#        Numeric Destination IP  dst_port_freq_encoded  Interarrival
# 4                  3758096386               0.017728           NaN
# 5                  3758096386               0.017728      0.000000
# 6                  3758096386               0.017728      0.187000
# 7                  3758096386               0.017728      0.000000
# 26                 3758096386               0.017728      4.087000
# ...                       ...                    ...           ...
# 38585              3270968577               0.000054      0.000360
# 38586              3270968603               0.000376     10.522429
# 38587              3270968577               0.000054      0.000545
# 38588              3270968603               0.000376     12.588217
# 38589              3270968577               0.000054      0.000547
#
# [18615 rows x 12 columns]

# %%
malicious_features.pop("Payload")
benign_features.pop("Payload")
# Out:
# 4           Raw
# 5           Raw
# 6           Raw
# 7           Raw
# 26          Raw
#           ...
# 38585    Radius
# 38586    Radius
# 38587    Radius
# 38588    Radius
# 38589    Radius
# Name: Payload, Length: 18615, dtype: object

# %% [markdown]
# # EDA
#
# Exploratory Data Analysis approaches the dataset as a black box that we need to visualize and analyze statistically with the following goals:
# - get insights about our data
# - test hypotheses
# - decide on models and further processing, such as feature engineering.
#
# EDA can be performed for benign and malicious data. Here we are looking at EDA only for malicious data, however the same functions can be applied to benign.

# %% [markdown]
# ## Descriptive statistics & data
#
# - Describe columns and data types
# - Descriptive statistics
#   -  count,
#   -  mean,
#   -  standard deviation,
#   -  minimum,
#   -  25th percentile,
#   -  median (50th percentile),
#   -  75th percentile, and
#   -  maximum

# %%
malicious_features.describe()
# Out:
#           Timestamp    Source Port  Destination Port  Packet Length  \
# count  1.540900e+05  154090.000000     154090.000000  154090.000000
# mean   1.540450e+09   31461.554105       6758.415673      45.299890
# std    2.080248e+03   18801.836599       7691.364297      17.558657
# min    1.540446e+09       0.000000         23.000000      20.000000
# 25%    1.540448e+09   21897.000000         53.000000      40.000000
# 50%    1.540450e+09   32761.000000       8280.000000      48.000000
# 75%    1.540452e+09   50861.000000      10240.000000      48.000000
# max    1.540454e+09   65267.000000      65267.000000     166.000000
#
#             Protocol  src_ip_total_bytes  dst_ip_total_bytes  \
# count  154090.000000        1.540900e+05        1.540900e+05
# mean       13.348420        6.480438e+05        2.883691e+05
# std         5.180108        5.928930e+05        3.112853e+05
# min         6.000000        2.600000e+01        2.600000e+01
# 25%         6.000000        1.617865e+05        6.316800e+04
# 50%        17.000000        4.427145e+05        1.624365e+05
# 75%        17.000000        1.050067e+06        4.276460e+05
# max        17.000000        2.207294e+06        1.423395e+06
#
#        Numeric Source IP  Numeric Destination IP  dst_port_freq_encoded  \
# count       1.540900e+05            1.540900e+05          154090.000000
# mean        3.231670e+09            1.970533e+09               0.233578
# std         4.278200e+07            1.039605e+09               0.156511
# min         0.000000e+00            1.347441e+08               0.000006
# 25%         3.232236e+09            8.740708e+08               0.061432
# 50%         3.232236e+09            2.014854e+09               0.216419
# 75%         3.232236e+09            3.232236e+09               0.406152
# max         3.232236e+09            4.294967e+09               0.406152
#
#         Interarrival
# count  154089.000000
# mean        0.046317
# std         0.091788
# min        -0.000269
# 25%         0.000061
# 50%         0.001171
# 75%         0.051200
# max         1.176720

# %%
benign_features.describe()
# Out:
#           Timestamp   Source Port  Destination Port  Packet Length  \
# count  1.861500e+04  18615.000000      18615.000000   18615.000000
# mean   1.561492e+09  26100.062208      12621.709911     297.704110
# std    5.667702e+07  24859.356286      17691.465555     447.200549
# min    1.355254e+09      7.000000          7.000000       9.000000
# 25%    1.509911e+09   5690.000000       1303.000000      56.000000
# 50%    1.574093e+09  15020.000000       5690.000000     180.000000
# 75%    1.597832e+09  54505.500000      15020.000000     180.000000
# max    1.671036e+09  65535.000000      65535.000000    8780.000000
#
#            Protocol  src_ip_total_bytes  dst_ip_total_bytes  \
# count  18615.000000        1.861500e+04        1.861500e+04
# mean      15.524899        4.799977e+05        4.657947e+05
# std        6.462379        8.002136e+05        7.824794e+05
# min        6.000000        2.000000e+01        2.000000e+01
# 25%       17.000000        5.966000e+03        6.962000e+03
# 50%       17.000000        1.169920e+05        1.022400e+05
# 75%       17.000000        4.722740e+05        4.641315e+05
# max       47.000000        2.760212e+06        2.732799e+06
#
#        Numeric Source IP  Numeric Destination IP  dst_port_freq_encoded  \
# count       1.861500e+04            1.861500e+04           18615.000000
# mean        2.673749e+09            2.754457e+09               0.078901
# std         1.059710e+09            1.059214e+09               0.075002
# min         0.000000e+00            1.684301e+07               0.000054
# 25%         1.418889e+09            1.418889e+09               0.009079
# 50%         3.232237e+09            3.232237e+09               0.049530
# 75%         3.239633e+09            3.628225e+09               0.172710
# max         3.640661e+09            4.294967e+09               0.180929
#
#        Interarrival
# count  1.861400e+04
# mean   1.696476e+04
# std    5.601252e+05
# min   -9.703636e-05
# 25%    3.480911e-05
# 50%    4.282355e-03
# 75%    1.757365e-02
# max    3.504942e+07

# %%
mirai_correlation_matrix = malicious_features.corr()
mirai_correlation_matrix
# Out:
#                         Timestamp  Source Port  Destination Port  \
# Timestamp                1.000000    -0.128160          0.069707
# Source Port             -0.128160     1.000000         -0.060443
# Destination Port         0.069707    -0.060443          1.000000
# Packet Length           -0.131946    -0.165664         -0.027235
# Protocol                -0.177842     0.031855          0.019889
# src_ip_total_bytes       0.518957     0.142800          0.114645
# dst_ip_total_bytes       0.455726    -0.165874         -0.206290
# Numeric Source IP        0.011192     0.022104          0.011517
# Numeric Destination IP   0.153173    -0.500735         -0.130771
# dst_port_freq_encoded   -0.148588     0.332926          0.152054
# Interarrival            -0.063879    -0.058298         -0.243491
#
#                         Packet Length  Protocol  src_ip_total_bytes  \
# Timestamp                   -0.131946 -0.177842            0.518957
# Source Port                 -0.165664  0.031855            0.142800
# Destination Port            -0.027235  0.019889            0.114645
# Packet Length                1.000000  0.545078           -0.044515
# Protocol                     0.545078  1.000000            0.107061
# src_ip_total_bytes          -0.044515  0.107061            1.000000
# dst_ip_total_bytes           0.149489  0.308723            0.204632
# Numeric Source IP           -0.091002 -0.009332            0.014418
# Numeric Destination IP       0.221897  0.005004           -0.391377
# dst_port_freq_encoded        0.148888  0.757495            0.383237
# Interarrival                 0.026269  0.061819           -0.122832
#
#                         dst_ip_total_bytes  Numeric Source IP  \
# Timestamp                         0.455726           0.011192
# Source Port                      -0.165874           0.022104
# Destination Port                 -0.206290           0.011517
# Packet Length                     0.149489          -0.091002
# Protocol                          0.308723          -0.009332
# src_ip_total_bytes                0.204632           0.014418
# dst_ip_total_bytes                1.000000           0.011855
# Numeric Source IP                 0.011855           1.000000
# Numeric Destination IP            0.262773          -0.029600
# dst_port_freq_encoded             0.136437           0.019742
# Interarrival                      0.157076          -0.004191
#
#                         Numeric Destination IP  dst_port_freq_encoded  \
# Timestamp                             0.153173              -0.148588
# Source Port                          -0.500735               0.332926
# Destination Port                     -0.130771               0.152054
# Packet Length                         0.221897               0.148888
# Protocol                              0.005004               0.757495
# src_ip_total_bytes                   -0.391377               0.383237
# dst_ip_total_bytes                    0.262773               0.136437
# Numeric Source IP                    -0.029600               0.019742
# Numeric Destination IP                1.000000              -0.340534
# dst_port_freq_encoded                -0.340534               1.000000
# Interarrival                          0.040813              -0.067594
#
#                         Interarrival
# Timestamp                  -0.063879
# Source Port                -0.058298
# Destination Port           -0.243491
# Packet Length               0.026269
# Protocol                    0.061819
# src_ip_total_bytes         -0.122832
# dst_ip_total_bytes          0.157076
# Numeric Source IP          -0.004191
# Numeric Destination IP      0.040813
# dst_port_freq_encoded      -0.067594
# Interarrival                1.000000

# %%
benign_correlation_matrix = benign_features.corr()
benign_correlation_matrix
# Out:
#                         Timestamp  Source Port  Destination Port  \
# Timestamp                1.000000    -0.238044          0.175399
# Source Port             -0.238044     1.000000         -0.364698
# Destination Port         0.175399    -0.364698          1.000000
# Packet Length           -0.175670     0.385247         -0.105459
# Protocol                -0.137366    -0.001969         -0.178826
# src_ip_total_bytes      -0.385764     0.547512         -0.281545
# dst_ip_total_bytes      -0.376098     0.574038         -0.281247
# Numeric Source IP        0.027331     0.340619         -0.343660
# Numeric Destination IP  -0.180346    -0.041412          0.008705
# dst_port_freq_encoded   -0.257925     0.384128         -0.407315
# Interarrival            -0.020904    -0.000208         -0.017173
#
#                         Packet Length  Protocol  src_ip_total_bytes  \
# Timestamp                   -0.175670 -0.137366           -0.385764
# Source Port                  0.385247 -0.001969            0.547512
# Destination Port            -0.105459 -0.178826           -0.281545
# Packet Length                1.000000 -0.020476            0.237230
# Protocol                    -0.020476  1.000000            0.088461
# src_ip_total_bytes           0.237230  0.088461            1.000000
# dst_ip_total_bytes           0.243572  0.082099            0.960583
# Numeric Source IP            0.058364  0.108441            0.217656
# Numeric Destination IP       0.110793  0.123732            0.189778
# dst_port_freq_encoded        0.303754  0.215613            0.530767
# Interarrival                -0.012279  0.002431           -0.018029
#
#                         dst_ip_total_bytes  Numeric Source IP  \
# Timestamp                        -0.376098           0.027331
# Source Port                       0.574038           0.340619
# Destination Port                 -0.281247          -0.343660
# Packet Length                     0.243572           0.058364
# Protocol                          0.082099           0.108441
# src_ip_total_bytes                0.960583           0.217656
# dst_ip_total_bytes                1.000000           0.218065
# Numeric Source IP                 0.218065           1.000000
# Numeric Destination IP            0.178040          -0.166954
# dst_port_freq_encoded             0.556927           0.439716
# Interarrival                     -0.017907           0.003683
#
#                         Numeric Destination IP  dst_port_freq_encoded  \
# Timestamp                            -0.180346              -0.257925
# Source Port                          -0.041412               0.384128
# Destination Port                      0.008705              -0.407315
# Packet Length                         0.110793               0.303754
# Protocol                              0.123732               0.215613
# src_ip_total_bytes                    0.189778               0.530767
# dst_ip_total_bytes                    0.178040               0.556927
# Numeric Source IP                    -0.166954               0.439716
# Numeric Destination IP                1.000000              -0.197721
# dst_port_freq_encoded                -0.197721               1.000000
# Interarrival                          0.002715              -0.025356
#
#                         Interarrival
# Timestamp                  -0.020904
# Source Port                -0.000208
# Destination Port           -0.017173
# Packet Length              -0.012279
# Protocol                    0.002431
# src_ip_total_bytes         -0.018029
# dst_ip_total_bytes         -0.017907
# Numeric Source IP           0.003683
# Numeric Destination IP      0.002715
# dst_port_freq_encoded      -0.025356
# Interarrival                1.000000

# %%
# Create a heatmap
def correlation_heatmap(correlation_matrix):
    plt.figure(figsize=(8, 6))  # Adjust the figure size as needed
    sns.set(font_scale=1.2)  # Adjust the font size as needed

    # Customize the heatmap
    sns.heatmap(
        correlation_matrix,
        annot=True,
        cmap="coolwarm",
        square=True,
        xticklabels=[
            "Timestamp",
            "Source Port",
            "Destination Port",
            "Packet Length",
            "Protocol",
            "src_ip_total_bytes",
            "dst_ip_total_bytes",
            "Number of Packets",
            "Source IP numeric",
            "Destination IP numeric",
            "dst_port_freq_encoded",
            "Interarrival",
        ],
        yticklabels=[
            "Timestamp",
            "Source Port",
            "Destination Port",
            "Packet Length",
            "Protocol",
            "src_ip_total_bytes",
            "dst_ip_total_bytes",
            "Number of Packets",
            "Source IP numeric",
            "Destination IP numeric",
            "dst_port_freq_encoded",
            "Interarrival",
        ],
    )

    plt.title("Correlation Heatmap")
    plt.show()

# %%
correlation_heatmap(mirai_correlation_matrix)

# %%
correlation_heatmap(benign_correlation_matrix)

# %% [markdown]
# ## Hypothesis testing
#
# How do datapoints influence one another?
# - Types of variables
#   - dependent: the effect of a phenomenon. For example, how does number of HTTP requests mean that a network is compromised?
#   - independent: the cause. The number of HTTP requests affects whether a network is compromised.

# %%
def hypothesis_testing(df, col1, col2):
    group1 = df[col1]
    group2 = df[col2]
    pvalue = ttest_ind(group1, group2)[1]
    if pvalue < 0.05:
        return "The difference between {} and {} is statistically significant (p < 0.05)".format(
            col1, col2
        )
    else:
        return "The difference between {} and {} is not statistically significant (p >= 0.05)".format(
            col1, col2
        )

# %%
hypothesis_testing(malicious_features, "dst_port_freq_encoded", "Packet Length")
# Out:
# 'The difference between dst_port_freq_encoded and Packet Length is statistically significant (p < 0.05)'

# %%
hypothesis_testing(benign_features, "dst_port_freq_encoded", "Packet Length")
# Out:
# 'The difference between dst_port_freq_encoded and Packet Length is statistically significant (p < 0.05)'

# %% [markdown]
# ## Outliers
#
# - observation that significantly differs from others in a dataset
# - Causes
#   - measurement errors
#   - extreme rare values
# - significant impact in statistical analysis
# - measurements
#   - z-score: `(x - mean) / std_dev`
#   - IQR method: this method identifies outliers as observations that are below `Q1 - 1.5IQR` or above `Q3 + 1.5IQR`, where Q1 and Q3 are the first and third quartiles, and IQR is the interquartile range (the difference between Q3 and Q1).
#   - visual inspection

# %%
def detect_outliers_zscore(df, column, threshold=3):
    zscores = np.abs(zscore(df[column]))
    return df[zscores > threshold]

# %%
outliers = detect_outliers_zscore(malicious_features, "Packet Length", threshold=3)
print(outliers)
# Out:
#            Timestamp  Source Port  Destination Port  Packet Length  Protocol  \
# 89      1.540446e+09      43537.0            1900.0            145      17.0
# 581     1.540446e+09       1215.0            1900.0            166      17.0
# 582     1.540446e+09       1215.0            1900.0            166      17.0
# 583     1.540446e+09       1215.0            1900.0            166      17.0
# 1012    1.540446e+09         67.0              68.0            166      17.0
# ...              ...          ...               ...            ...       ...
# 754911  1.540453e+09       1215.0            1900.0            166      17.0
# 762373  1.540454e+09       1215.0            1900.0            166      17.0
# 762374  1.540454e+09       1215.0            1900.0            166      17.0
# 762375  1.540454e+09       1215.0            1900.0            166      17.0
# 763551  1.540454e+09         67.0              68.0            166      17.0
#
#         src_ip_total_bytes  dst_ip_total_bytes  Numeric Source IP  \
# 89                     193                 145         3232236141
# 581                   2000                 311         3232236147
# 582                   2166                 477         3232236147
# 583                   2332                 643         3232236147
# 1012                  1791                 166         3232236033
# ...                    ...                 ...                ...
# 754911              879049              172626         3232236147
# 762373              882467              172792         3232236147
# 762374              882633              172958         3232236147
# 762375              882799              173124         3232236147
# 763551              478257               27058         3232236033
#
#         Numeric Destination IP  dst_port_freq_encoded  Interarrival
# 89                  4026531834               0.006827      0.026332
# 581                 4026531834               0.006827      0.107952
# 582                 4026531834               0.006827      0.000148
# 583                 4026531834               0.006827      0.000002
# 1012                4294967295               0.000883      0.034520
# ...                        ...                    ...           ...
# 754911              4026531834               0.006827      0.000095
# 762373              4026531834               0.006827      0.292217
# 762374              4026531834               0.006827      0.001491
# 762375              4026531834               0.006827      0.000639
# 763551              4294967295               0.000883      0.046482
#
# [1542 rows x 11 columns]

# %%
outliers = detect_outliers_zscore(benign_features, "Packet Length", threshold=3)
print(outliers)
# Out:
#           Timestamp  Source Port  Destination Port  Packet Length  Protocol  \
# 1993   1.460283e+09        443.0           50477.0           2928       6.0
# 2062   1.460283e+09      45271.0              25.0           7272       6.0
# 2063   1.460283e+09      45271.0              25.0           3097       6.0
# 14426  1.560870e+09         53.0           39005.0           1764       6.0
# 23800  1.589384e+09      11371.0           39638.0           4272       6.0
# 23801  1.589384e+09      11371.0           39638.0           4116       6.0
# 23802  1.589384e+09      11371.0           39638.0           3859       6.0
# 23887  1.597832e+09      65439.0            9100.0           8780       6.0
# 23893  1.597832e+09      65439.0            9100.0           2940       6.0
# 23895  1.597832e+09      65439.0            9100.0           4400       6.0
# 23897  1.597832e+09      65439.0            9100.0           4400       6.0
# 23899  1.597832e+09      65439.0            9100.0           4400       6.0
# 23901  1.597832e+09      65439.0            9100.0           4400       6.0
# 23903  1.597832e+09      65439.0            9100.0           2940       6.0
# 23905  1.597832e+09      65439.0            9100.0           2940       6.0
# 23907  1.597832e+09      65439.0            9100.0           4400       6.0
# 23909  1.597832e+09      65439.0            9100.0           4400       6.0
# 23911  1.597832e+09      65439.0            9100.0           2940       6.0
# 23913  1.597832e+09      65439.0            9100.0           4400       6.0
# 23915  1.597832e+09      65439.0            9100.0           4400       6.0
# 23917  1.597832e+09      65439.0            9100.0           2940       6.0
# 23919  1.597832e+09      65439.0            9100.0           3979       6.0
# 25147  1.597834e+09      57895.0             515.0           7320       6.0
# 25149  1.597834e+09      57895.0             515.0           4400       6.0
# 25152  1.597834e+09      57895.0             515.0           7320       6.0
# 25155  1.597834e+09      57895.0             515.0           8780       6.0
# 25157  1.597834e+09      57895.0             515.0           2940       6.0
# 25159  1.597834e+09      57895.0             515.0           4400       6.0
# 25161  1.597834e+09      57895.0             515.0           4400       6.0
# 25164  1.597834e+09      57895.0             515.0           8780       6.0
# 25167  1.597834e+09      57895.0             515.0           7320       6.0
# 25169  1.597834e+09      57895.0             515.0           4400       6.0
# 25171  1.597834e+09      57895.0             515.0           3955       6.0
# 35815  1.623071e+09       6514.0           33509.0           1835       6.0
# 36580  1.657872e+09      49410.0           10051.0           5376       6.0
# 36610  1.657872e+09      10051.0           49416.0           4255       6.0
# 36628  1.657872e+09      49420.0           10051.0           4655       6.0
# 36756  1.657899e+09      60388.0           10051.0           4359       6.0
# 36984  1.657899e+09      10051.0           36520.0           5587       6.0
# 37084  1.667034e+09      10051.0           59326.0           2928       6.0
# 37102  1.667034e+09      55826.0           10051.0           7272       6.0
# 37104  1.667034e+09      55826.0           10051.0           4841       6.0
# 37142  1.667034e+09      54614.0           10051.0           3200       6.0
# 37172  1.667034e+09      10051.0           36596.0           4039       6.0
# 37190  1.667034e+09      54958.0           10051.0           5038       6.0
# 37228  1.667034e+09      53190.0           10051.0           4101       6.0
#
#        src_ip_total_bytes  dst_ip_total_bytes  Numeric Source IP  \
# 1993                 3000                3864         1352297707
# 2062                 9737                7588         3232263689
# 2063                12834               10685         3232263689
# 14426                1836                3316         3270968590
# 23800                4356               42326         2731876617
# 23801                8472               46442         2731876617
# 23802               12331               50301         2731876617
# 23887                8832                8832          173193483
# 23893               13337               13337          173193483
# 23895               17737               17737          173193483
# 23897               22137               22137          173193483
# 23899               26537               26537          173193483
# 23901               30937               30937          173193483
# 23903               33877               33877          173193483
# 23905               36817               36817          173193483
# 23907               41217               41217          173193483
# 23909               45617               45617          173193483
# 23911               48557               48557          173193483
# 23913               52957               52957          173193483
# 23915               57357               57357          173193483
# 23917               60297               60297          173193483
# 23919               64276               64276          173193483
# 25147               71992               71992          173193483
# 25149               76392               76392          173193483
# 25152               83712               83712          173193483
# 25155               92492               92492          173193483
# 25157               95432               95432          173193483
# 25159               99832               99832          173193483
# 25161              104232              104232          173193483
# 25164              113012              113012          173193483
# 25167              120332              120332          173193483
# 25169              124732              124732          173193483
# 25171              128687              128687          173193483
# 35815                8640                1907         3270968582
# 36580                6507                6507         3232237328
# 36610                5621                5621         3232237329
# 36628               12591               12591         3232237328
# 36756                7311               20367         3232237327
# 36984               19807               13307         3232237329
# 37084               18350               31406         3232237327
# 37102               29912               23412         3232237329
# 37104               34753               28253         3232237329
# 37142               39098               32598         3232237329
# 37172               24459               37515         3232237327
# 37190               45533               39033         3232237329
# 37228               50781               44281         3232237329
#
#        Numeric Destination IP  dst_port_freq_encoded  Interarrival
# 1993               3232263689               0.000430      0.004540
# 2062               1352297709               0.000591      0.000069
# 2063               1352297709               0.000591      0.000188
# 14426              3270968582               0.000269      0.000462
# 23800              3239633894               0.000430      0.009700
# 23801              3239633894               0.000430      0.000054
# 23802              3239633894               0.000430      0.000008
# 23887              3232238346               0.001021      0.004028
# 23893              3232238346               0.001021      0.000022
# 23895              3232238346               0.001021      0.000034
# 23897              3232238346               0.001021      0.000063
# 23899              3232238346               0.001021      0.000029
# 23901              3232238346               0.001021      0.000022
# 23903              3232238346               0.001021      0.000016
# 23905              3232238346               0.001021      0.000063
# 23907              3232238346               0.001021      0.000030
# 23909              3232238346               0.001021      0.000016
# 23911              3232238346               0.001021      0.000014
# 23913              3232238346               0.001021      0.000014
# 23915              3232238346               0.001021      0.000022
# 23917              3232238346               0.001021      0.000046
# 23919              3232238346               0.001021      0.000040
# 25147              3232238346               0.001021      0.000146
# 25149              3232238346               0.001021      0.000181
# 25152              3232238346               0.001021      0.000017
# 25155              3232238346               0.001021      0.000046
# 25157              3232238346               0.001021      0.000014
# 25159              3232238346               0.001021      0.000016
# 25161              3232238346               0.001021      0.000031
# 25164              3232238346               0.001021      0.000100
# 25167              3232238346               0.001021      0.000071
# 25169              3232238346               0.001021      0.000033
# 25171              3232238346               0.001021      0.000017
# 35815              3270968592               0.000430      0.021730
# 36580              3232237329               0.020038      0.000058
# 36610              3232237328               0.000269      0.004065
# 36628              3232237329               0.020038      0.000075
# 36756              3232237329               0.020038      0.000103
# 36984              3232237327               0.000269      0.002046
# 37084              3232237329               0.000269      0.002184
# 37102              3232237327               0.020038      0.000601
# 37104              3232237327               0.020038      0.000019
# 37142              3232237327               0.020038      0.000111
# 37172              3232237329               0.000269      0.001682
# 37190              3232237327               0.020038      0.000065
# 37228              3232237327               0.020038      0.000057

# %%
def plot_outliers_multiple_views(df, column, threshold=3):
    """
    Creates a comprehensive view of outliers using multiple plots:
    1. Box plot
    2. Scatter plot with z-scores
    3. Distribution plot with outlier regions marked
    
    Parameters:
    df (pandas.DataFrame): Input dataframe
    column (str): Column name to analyze
    threshold (float): Z-score threshold for outlier detection
    """
    # Calculate z-scores
    z_scores = zscore(df[column])
    df_with_z = df.copy()
    df_with_z['zscore'] = z_scores
    df_with_z['is_outlier'] = np.abs(z_scores) > threshold
    
    # Create a figure with three subplots
    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 15))
    
    # 1. Box Plot
    sns.boxplot(x=df[column], ax=ax1)
    ax1.set_title('Box Plot with Outliers')
    
    # 2. Scatter Plot with z-scores
    scatter_colors = ['blue' if not outlier else 'red' for outlier in df_with_z['is_outlier']]
    ax2.scatter(range(len(df_with_z)), df_with_z[column], c=scatter_colors, alpha=0.5)
    ax2.axhline(y=df[column].mean(), color='green', linestyle='--', label='Mean')
    ax2.set_title('Scatter Plot (Red Points are Outliers)')
    ax2.set_xlabel('Index')
    ax2.set_ylabel('Value')
    ax2.legend()
    
    # 3. Distribution Plot with Outlier Regions
    sns.kdeplot(data=df[column], ax=ax3)
    outliers = df_with_z[df_with_z['is_outlier']][column]
    if len(outliers) > 0:
        ax3.hist(outliers, bins=10, alpha=0.5, color='red', density=True)
    ax3.set_title('Distribution with Outliers Highlighted')
    
    # Add threshold lines to distribution plot
    mean = df[column].mean()
    std = df[column].std()
    ax3.axvline(mean + threshold * std, color='r', linestyle='--', alpha=0.5)
    ax3.axvline(mean - threshold * std, color='r', linestyle='--', alpha=0.5)
    
    plt.tight_layout()
    return fig

def plot_outlier_details(df, column, threshold=3):
    """
    Creates a detailed analysis plot focusing on the outliers' z-scores
    
    Parameters:
    df (pandas.DataFrame): Input dataframe
    column (str): Column name to analyze
    threshold (float): Z-score threshold for outlier detection
    """
    # Calculate z-scores
    z_scores = zscore(df[column])
    df_with_z = df.copy()
    df_with_z['zscore'] = z_scores
    df_with_z['is_outlier'] = np.abs(z_scores) > threshold
    
    # Create figure
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))
    
    # 1. Z-score distribution
    sns.histplot(data=df_with_z, x='zscore', ax=ax1)
    ax1.axvline(x=threshold, color='r', linestyle='--', label=f'Threshold (+{threshold})')
    ax1.axvline(x=-threshold, color='r', linestyle='--', label=f'Threshold (-{threshold})')
    ax1.set_title('Z-score Distribution')
    ax1.legend()
    
    # 2. Z-score vs Original Value scatter
    non_outliers = df_with_z[~df_with_z['is_outlier']]
    outliers = df_with_z[df_with_z['is_outlier']]
    
    ax2.scatter(non_outliers['zscore'], non_outliers[column], 
                c='blue', label='Normal', alpha=0.5)
    ax2.scatter(outliers['zscore'], outliers[column], 
                c='red', label='Outliers', alpha=0.5)
    ax2.axvline(x=threshold, color='r', linestyle='--', alpha=0.3)
    ax2.axvline(x=-threshold, color='r', linestyle='--', alpha=0.3)
    ax2.set_xlabel('Z-score')
    ax2.set_ylabel('Original Value')
    ax2.set_title('Z-score vs Original Value')
    ax2.legend()
    
    plt.tight_layout()
    return fig

# %%
# Create both visualizations
fig1 = plot_outliers_multiple_views(malicious_features, "Packet Length", threshold=3)
fig2 = plot_outlier_details(malicious_features, "Packet Length", threshold=3)

# Display the plots
plt.show()

# %% [markdown]
# # Summaries & Visualizations
# Using packages `dfSummary` and `sweetviz`, we create a wealth of visualizations with minimal code. These visualizations offer valuable insights for data exploration.

# %%
dfSummary(malicious_features)
# Out:
# <style type="text/css">
# #T_fab26 thead>tr>th {
#   text-align: left;
# }
# #T_fab26_row0_col0, #T_fab26_row1_col0, #T_fab26_row2_col0, #T_fab26_row3_col0, #T_fab26_row4_col0, #T_fab26_row5_col0, #T_fab26_row6_col0, #T_fab26_row7_col0, #T_fab26_row8_col0, #T_fab26_row9_col0, #T_fab26_row10_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_fab26_row0_col1, #T_fab26_row1_col1, #T_fab26_row2_col1, #T_fab26_row3_col1, #T_fab26_row4_col1, #T_fab26_row5_col1, #T_fab26_row6_col1, #T_fab26_row7_col1, #T_fab26_row8_col1, #T_fab26_row9_col1, #T_fab26_row10_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_fab26_row0_col2, #T_fab26_row1_col2, #T_fab26_row2_col2, #T_fab26_row3_col2, #T_fab26_row4_col2, #T_fab26_row5_col2, #T_fab26_row6_col2, #T_fab26_row7_col2, #T_fab26_row8_col2, #T_fab26_row9_col2, #T_fab26_row10_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_fab26_row0_col3, #T_fab26_row1_col3, #T_fab26_row2_col3, #T_fab26_row3_col3, #T_fab26_row4_col3, #T_fab26_row5_col3, #T_fab26_row6_col3, #T_fab26_row7_col3, #T_fab26_row8_col3, #T_fab26_row9_col3, #T_fab26_row10_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_fab26_row0_col4, #T_fab26_row1_col4, #T_fab26_row2_col4, #T_fab26_row3_col4, #T_fab26_row4_col4, #T_fab26_row5_col4, #T_fab26_row6_col4, #T_fab26_row7_col4, #T_fab26_row8_col4, #T_fab26_row9_col4, #T_fab26_row10_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_fab26_row0_col5, #T_fab26_row1_col5, #T_fab26_row2_col5, #T_fab26_row3_col5, #T_fab26_row4_col5, #T_fab26_row5_col5, #T_fab26_row6_col5, #T_fab26_row7_col5, #T_fab26_row8_col5, #T_fab26_row9_col5, #T_fab26_row10_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_fab26">
#   <caption><strong>Data Frame Summary</strong><br>malicious_features<br>Dimensions: 154,090 x 11<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_fab26_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_fab26_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_fab26_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_fab26_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_fab26_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_fab26_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fab26_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_fab26_row0_col1" class="data row0 col1" ><strong>Timestamp</strong><br>[float64]</td>
#       <td id="T_fab26_row0_col2" class="data row0 col2" >Mean (sd) : 1540450214.8 (2080.2)<br>min < med < max:<br>1540446382.9 < 1540450432.6 < 1540453519.8<br>IQR (CV) : 3618.0 (740512.8)</td>
#       <td id="T_fab26_row0_col3" class="data row0 col3" >154,090 distinct values</td>
#       <td id="T_fab26_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_fab26_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_fab26_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_fab26_row1_col1" class="data row1 col1" ><strong>Source Port</strong><br>[float64]</td>
#       <td id="T_fab26_row1_col2" class="data row1 col2" >Mean (sd) : 31461.6 (18801.8)<br>min < med < max:<br>0.0 < 32761.0 < 65267.0<br>IQR (CV) : 28964.0 (1.7)</td>
#       <td id="T_fab26_row1_col3" class="data row1 col3" >22,952 distinct values</td>
#       <td id="T_fab26_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_fab26_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_fab26_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_fab26_row2_col1" class="data row2 col1" ><strong>Destination Port</strong><br>[float64]</td>
#       <td id="T_fab26_row2_col2" class="data row2 col2" >Mean (sd) : 6758.4 (7691.4)<br>min < med < max:<br>23.0 < 8280.0 < 65267.0<br>IQR (CV) : 10187.0 (0.9)</td>
#       <td id="T_fab26_row2_col3" class="data row2 col3" >3,691 distinct values</td>
#       <td id="T_fab26_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_fab26_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_fab26_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_fab26_row3_col1" class="data row3 col1" ><strong>Packet Length</strong><br>[int64]</td>
#       <td id="T_fab26_row3_col2" class="data row3 col2" >Mean (sd) : 45.3 (17.6)<br>min < med < max:<br>20.0 < 48.0 < 166.0<br>IQR (CV) : 8.0 (2.6)</td>
#       <td id="T_fab26_row3_col3" class="data row3 col3" >84 distinct values</td>
#       <td id="T_fab26_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_fab26_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_fab26_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_fab26_row4_col1" class="data row4 col1" ><strong>Protocol</strong><br>[float64]</td>
#       <td id="T_fab26_row4_col2" class="data row4 col2" >1. 17.0<br>2. 6.0</td>
#       <td id="T_fab26_row4_col3" class="data row4 col3" >102,938 (66.8%)<br>51,152 (33.2%)</td>
#       <td id="T_fab26_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_fab26_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_fab26_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_fab26_row5_col1" class="data row5 col1" ><strong>src_ip_total_bytes</strong><br>[int64]</td>
#       <td id="T_fab26_row5_col2" class="data row5 col2" >Mean (sd) : 648043.8 (592893.0)<br>min < med < max:<br>26.0 < 442714.5 < 2207294.0<br>IQR (CV) : 888280.2 (1.1)</td>
#       <td id="T_fab26_row5_col3" class="data row5 col3" >145,355 distinct values</td>
#       <td id="T_fab26_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_fab26_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_fab26_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_fab26_row6_col1" class="data row6 col1" ><strong>dst_ip_total_bytes</strong><br>[int64]</td>
#       <td id="T_fab26_row6_col2" class="data row6 col2" >Mean (sd) : 288369.1 (311285.3)<br>min < med < max:<br>26.0 < 162436.5 < 1423395.0<br>IQR (CV) : 364478.0 (0.9)</td>
#       <td id="T_fab26_row6_col3" class="data row6 col3" >108,056 distinct values</td>
#       <td id="T_fab26_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_fab26_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_fab26_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_fab26_row7_col1" class="data row7 col1" ><strong>Numeric Source IP</strong><br>[int64]</td>
#       <td id="T_fab26_row7_col2" class="data row7 col2" >Mean (sd) : 3231669778.3 (42782000.9)<br>min < med < max:<br>0.0 < 3232236142.0 < 3232236228.0<br>IQR (CV) : 5.0 (75.5)</td>
#       <td id="T_fab26_row7_col3" class="data row7 col3" >22 distinct values</td>
#       <td id="T_fab26_row7_col4" class="data row7 col4" ><img src = "......"></img></td>
#       <td id="T_fab26_row7_col5" class="data row7 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_fab26_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_fab26_row8_col1" class="data row8 col1" ><strong>Numeric Destination IP</strong><br>[int64]</td>
#       <td id="T_fab26_row8_col2" class="data row8 col2" >Mean (sd) : 1970532932.1 (1039604758.0)<br>min < med < max:<br>134744072.0 < 2014854038.0 < 4294967295.0<br>IQR (CV) : 2358165255.0 (1.9)</td>
#       <td id="T_fab26_row8_col3" class="data row8 col3" >63 distinct val

# %%
dfSummary(benign_features)
# Out:
# <style type="text/css">
# #T_e5edd thead>tr>th {
#   text-align: left;
# }
# #T_e5edd_row0_col0, #T_e5edd_row1_col0, #T_e5edd_row2_col0, #T_e5edd_row3_col0, #T_e5edd_row4_col0, #T_e5edd_row5_col0, #T_e5edd_row6_col0, #T_e5edd_row7_col0, #T_e5edd_row8_col0, #T_e5edd_row9_col0, #T_e5edd_row10_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_e5edd_row0_col1, #T_e5edd_row1_col1, #T_e5edd_row2_col1, #T_e5edd_row3_col1, #T_e5edd_row4_col1, #T_e5edd_row5_col1, #T_e5edd_row6_col1, #T_e5edd_row7_col1, #T_e5edd_row8_col1, #T_e5edd_row9_col1, #T_e5edd_row10_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_e5edd_row0_col2, #T_e5edd_row1_col2, #T_e5edd_row2_col2, #T_e5edd_row3_col2, #T_e5edd_row4_col2, #T_e5edd_row5_col2, #T_e5edd_row6_col2, #T_e5edd_row7_col2, #T_e5edd_row8_col2, #T_e5edd_row9_col2, #T_e5edd_row10_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_e5edd_row0_col3, #T_e5edd_row1_col3, #T_e5edd_row2_col3, #T_e5edd_row3_col3, #T_e5edd_row4_col3, #T_e5edd_row5_col3, #T_e5edd_row6_col3, #T_e5edd_row7_col3, #T_e5edd_row8_col3, #T_e5edd_row9_col3, #T_e5edd_row10_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_e5edd_row0_col4, #T_e5edd_row1_col4, #T_e5edd_row2_col4, #T_e5edd_row3_col4, #T_e5edd_row4_col4, #T_e5edd_row5_col4, #T_e5edd_row6_col4, #T_e5edd_row7_col4, #T_e5edd_row8_col4, #T_e5edd_row9_col4, #T_e5edd_row10_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_e5edd_row0_col5, #T_e5edd_row1_col5, #T_e5edd_row2_col5, #T_e5edd_row3_col5, #T_e5edd_row4_col5, #T_e5edd_row5_col5, #T_e5edd_row6_col5, #T_e5edd_row7_col5, #T_e5edd_row8_col5, #T_e5edd_row9_col5, #T_e5edd_row10_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_e5edd">
#   <caption><strong>Data Frame Summary</strong><br>benign_features<br>Dimensions: 18,615 x 11<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_e5edd_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_e5edd_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_e5edd_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_e5edd_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_e5edd_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_e5edd_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e5edd_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e5edd_row0_col1" class="data row0 col1" ><strong>Timestamp</strong><br>[float64]</td>
#       <td id="T_e5edd_row0_col2" class="data row0 col2" >Mean (sd) : 1561492241.7 (56677016.7)<br>min < med < max:<br>1355253962.7 < 1574093294.6 < 1671035961.3<br>IQR (CV) : 87921040.3 (27.6)</td>
#       <td id="T_e5edd_row0_col3" class="data row0 col3" >18,312 distinct values</td>
#       <td id="T_e5edd_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_e5edd_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e5edd_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_e5edd_row1_col1" class="data row1 col1" ><strong>Source Port</strong><br>[float64]</td>
#       <td id="T_e5edd_row1_col2" class="data row1 col2" >Mean (sd) : 26100.1 (24859.4)<br>min < med < max:<br>7.0 < 15020.0 < 65535.0<br>IQR (CV) : 48815.5 (1.0)</td>
#       <td id="T_e5edd_row1_col3" class="data row1 col3" >960 distinct values</td>
#       <td id="T_e5edd_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_e5edd_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e5edd_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_e5edd_row2_col1" class="data row2 col1" ><strong>Destination Port</strong><br>[float64]</td>
#       <td id="T_e5edd_row2_col2" class="data row2 col2" >Mean (sd) : 12621.7 (17691.5)<br>min < med < max:<br>7.0 < 5690.0 < 65535.0<br>IQR (CV) : 13717.0 (0.7)</td>
#       <td id="T_e5edd_row2_col3" class="data row2 col3" >741 distinct values</td>
#       <td id="T_e5edd_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_e5edd_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e5edd_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_e5edd_row3_col1" class="data row3 col1" ><strong>Packet Length</strong><br>[int64]</td>
#       <td id="T_e5edd_row3_col2" class="data row3 col2" >Mean (sd) : 297.7 (447.2)<br>min < med < max:<br>9.0 < 180.0 < 8780.0<br>IQR (CV) : 124.0 (0.7)</td>
#       <td id="T_e5edd_row3_col3" class="data row3 col3" >878 distinct values</td>
#       <td id="T_e5edd_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_e5edd_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e5edd_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_e5edd_row4_col1" class="data row4 col1" ><strong>Protocol</strong><br>[float64]</td>
#       <td id="T_e5edd_row4_col2" class="data row4 col2" >1. 17.0<br>2. 6.0<br>3. 47.0<br>4. 41.0</td>
#       <td id="T_e5edd_row4_col3" class="data row4 col3" >14,450 (77.6%)<br>3,693 (19.8%)<br>306 (1.6%)<br>166 (0.9%)</td>
#       <td id="T_e5edd_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_e5edd_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e5edd_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_e5edd_row5_col1" class="data row5 col1" ><strong>src_ip_total_bytes</strong><br>[int64]</td>
#       <td id="T_e5edd_row5_col2" class="data row5 col2" >Mean (sd) : 479997.7 (800213.6)<br>min < med < max:<br>20.0 < 116992.0 < 2760212.0<br>IQR (CV) : 466308.0 (0.6)</td>
#       <td id="T_e5edd_row5_col3" class="data row5 col3" >16,223 distinct values</td>
#       <td id="T_e5edd_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_e5edd_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e5edd_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_e5edd_row6_col1" class="data row6 col1" ><strong>dst_ip_total_bytes</strong><br>[int64]</td>
#       <td id="T_e5edd_row6_col2" class="data row6 col2" >Mean (sd) : 465794.7 (782479.4)<br>min < med < max:<br>20.0 < 102240.0 < 2732799.0<br>IQR (CV) : 457169.5 (0.6)</td>
#       <td id="T_e5edd_row6_col3" class="data row6 col3" >16,551 distinct values</td>
#       <td id="T_e5edd_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_e5edd_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e5edd_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_e5edd_row7_col1" class="data row7 col1" ><strong>Numeric Source IP</strong><br>[int64]</td>
#       <td id="T_e5edd_row7_col2" class="data row7 col2" >Mean (sd) : 2673749377.7 (1059709514.3)<br>min < med < max:<br>0.0 < 3232237338.0 < 3640661313.0<br>IQR (CV) : 1820744027.0 (2.5)</td>
#       <td id="T_e5edd_row7_col3" class="data row7 col3" >180 distinct values</td>
#       <td id="T_e5edd_row7_col4" class="data row7 col4" ><img src = "......"></img></td>
#       <td id="T_e5edd_row7_col5" class="data row7 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e5edd_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_e5edd_row8_col1" class="data row8 col1" ><strong>Numeric Destination IP</strong><br>[int64]</td>
#       <td id="T_e5edd_row8_col2" class="data row8 col2" >Mean (sd) : 2754457230.3 (1059214054.3)<br>min < med < max:<br>16843009.0 < 3232237324.0 < 4294967295.0<br>IQR (CV) : 2209335361.0 (2.6)</td>
#       <td id="T

# %%
# import sweetviz as sv
# known error, branch unmerged https://github.com/fbdesignpro/sweetviz/pull/178
# my_report = sv.analyze(malicious_features)
# # this shows and saves the html to the specific path. Make sure the directory html exists.
# my_report.show_html(filepath="html/malicious.html")

# %%
# my_report = sv.analyze(benign_features)
# # this shows and saves the html to the specific path. Make sure the directory html exists.
# my_report.show_html(filepath="html/benign.html")
